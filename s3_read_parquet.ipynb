# %%
 # !pip install awswrangler
# Out:
# ...
#      |████████████████████████████████| 179 kB 6.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 91 kB 8.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 43 kB 2.7 MB/s  eta 0:00:01
# ...

# %%
from platform import python_version

print(python_version())
# Out:
# 3.6.13

# %%
import awswrangler as wr
df = wr.s3.read_parquet(path="s3://manjaha-aws-bucket-1/Adobe/Exclusion/Parquet/20210423_174734_00033_256dt_99bbb2a6-9032-4e77-ab7b-600b52ef7b5a")

# %%
df.dtypes
# Out:
# email                          string
# customer_type                  string
# customer_id                    string
# delivery_label                 string
# delivery_status                string
# delivery_date                  string
# delivery_reason                string
# tracking_date                  string
# tracking_type                  string
# exclusion_reason               string
# exclusion_nature_of_failure    string
# exclusion_failure_type         string
# exclusion_event_date           string
# exclusion_status               string
# delivery_id                    string
# acct_key                       string
# appl_key                       string
# acs_creative_group             string
# acs_group                      string
# campaign_key                   string
# contact_urn                    string
# rule_id                        string
# campaign_label                 string
# campaign_name                  string
# dtype: object

# %%
# !pip install pandasql
# Out:
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26818 sha256=70d8f3785ea27cf07198509adddda89cba19d8654f0ac04f93c534316b0f3f85
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/a6/64/11/62d5f7b88421a5d80068ac9937fe2915e497da3eba900c8f59
# Successfully built pandasql
# ...

# %%
from pandasql import sqldf

# %%
output = sqldf("select appl_key from df where appl_key is null")
output
# Out:
# Empty DataFrame
# Columns: [appl_key]
# Index: []

# %%
# Out:
#                                 email  customer_type  customer_id  \
# 0                               Email  Customer type  Customer ID
# 1          ivaldifransselle@gmail.com
# 2         abenavidez210117@icloud.com
# 3                  abu373us@yahoo.com
# 4                arehodes15@gmail.com
# 5         bedtinvestments@hotmail.com
# 6             tealaboyd2019@gmail.com
# 7                  deenieb1@gnail.com
# 8             cjgoscore111@icloud.com
# 9      corinnnejasonwolford@gmail.com
# 10           elephantfaga@hotmail.com
# 11               gmrtinezny@yahoo.com
# 12                      jg@copesg.com
# 13          jorinda_millerw@yahoo.com
# 14           kevin.hiwell@hotmail.com
# 15                    lisalmi@aol.com
# 16             llcdjlogstics@mail.com
# 17        marceloarbrlaez25@gmail.com
# 18            roxieamdmicha@gmail.com
# 19              sedri_mccoy@yahoo.com
# 20             steunyon2014@gmail.com
# 21            timeellsbikes@gmail.com
# ...
